# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
raw = [
    24, 1.76,
    50, 0.680,
    74, -0.080,
    100,-0.760,
    124, -1.24,
    150, -1.64,
    174, -1.88,
    200, -2.16,
    224, -2.32,
    250, -2.44,
    274, -2.56,
    300, -2.60,
    324, -2.72,
    350, -2.80,
]  
dat = np.array(raw)
t = dat[::2]
v = dat[1::2]
plt.plot(t,v,"o",label="data")
plt.ylim(-3.0,3.0)

R = 10E-9
C = 10E3
tau = R * C * 1E6

tx = np.linspace(0,350,20)
vx = 6*np.exp(-tx/tau)-3
plt.plot(tx,vx,"r-",label="prediction")
plt.xlabel("Time (Microseconds)")
plt.ylabel("Voltage (V)")
plt.legend()

plt.text(35.0, 2.5, "Physics 80 - Instructor Plot")
# Out:
# Text(35,2.5,'Physics 80 - Instructor Plot')
